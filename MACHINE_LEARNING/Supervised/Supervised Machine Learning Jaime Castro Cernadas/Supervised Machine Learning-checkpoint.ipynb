# %%
import pandas as pd
data= pd.read_csv("/Users/jaimecastro/Desktop/master/MACHINE_LEARNING/dataset10.csv")

# %% [markdown]
# # Initial Data Visualization

# %%
data.head()
# Out:
#    Unnamed: 0 Target  n_rs3188513  n_rs9960669  n_rs2602  n_rs5445365  \
# 0           0      R            0            2         0            0
# 1           1      R            1            0         0            0
# 2           2      R            1            0         2            1
# 3           3      R            0            2         0            1
# 4           4      R            0            2         2            0
#
#    n_rs133061  n_rs10102851  n_rs8375668  n_rs3015353  ...  n_rs9280789  \
# 0           1             2            1            0  ...            2
# 1           0             2            0            0  ...            2
# 2           0             0            0            1  ...            1
# 3           1             2            1            1  ...            2
# 4           1             2            0            1  ...            1
#
#    n_rs2515462  n_rs9025039  n_rs94282819  n_rs344903  n_rs0370  n_rs9072249  \
# ...

# %%
data.tail()
# Out:
#     Unnamed: 0 Target  n_rs3188513  n_rs9960669  n_rs2602  n_rs5445365  \
# 48          48     NR            2            2         2            2
# 49          49     NR            1            0         2            2
# 50          50      R            1            2         1            2
# 51          51     NR            1            2         2            0
# 52          52     NR            2            2         2            2
#
#     n_rs133061  n_rs10102851  n_rs8375668  n_rs3015353  ...  n_rs9280789  \
# 48           2             2            2            1  ...            2
# 49           2             2            0            1  ...            0
# 50           1             2            0            1  ...            2
# 51           1             2            2            2  ...            2
# 52           2             2            0            1  ...            2
#
#     n_rs2515462  n_rs9025039  n_rs94282819  n_rs344903  n_rs0370  n_rs9072249  \
# ...

# %%
data.describe()
# Out:
#        Unnamed: 0  n_rs3188513  n_rs9960669   n_rs2602  n_rs5445365  \
# count   53.000000    53.000000    53.000000  53.000000    53.000000
# mean    26.000000     0.830189     1.566038   1.188679     1.037736
# std     15.443445     0.802301     0.693637   0.833358     0.854001
# min      0.000000     0.000000     0.000000   0.000000     0.000000
# 25%     13.000000     0.000000     1.000000   0.000000     0.000000
# 50%     26.000000     1.000000     2.000000   1.000000     1.000000
# 75%     39.000000     1.000000     2.000000   2.000000     2.000000
# max     52.000000     2.000000     2.000000   2.000000     2.000000
#
#        n_rs133061  n_rs10102851  n_rs8375668  n_rs3015353  n_rs3229523  ...  \
# count   53.000000      53.00000    53.000000    53.000000    53.000000  ...
# mean     0.943396       1.54717     0.679245     0.792453     0.811321  ...
# std      0.818420       0.79822     0.826801     0.840295     0.856123  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 23 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    53 non-null     int64
#  1   Target        53 non-null     object
#  2   n_rs3188513   53 non-null     int64
#  3   n_rs9960669   53 non-null     int64
#  4   n_rs2602      53 non-null     int64
#  5   n_rs5445365   53 non-null     int64
#  6   n_rs133061    53 non-null     int64
#  7   n_rs10102851  53 non-null     int64
#  8   n_rs8375668   53 non-null     int64
#  9   n_rs3015353   53 non-null     int64
#  10  n_rs3229523   53 non-null     int64
#  11  n_rs6236416   53 non-null     int64
#  12  n_rs5274755   53 non-null     int64
#  13  n_rs9280789   53 non-null     int64
#  14  n_rs2515462   53 non-null     int64
#  15  n_rs9025039   53 non-null     int64
#  16  n_rs94282819  53 non-null     int64
#  17  n_rs344903    53 non-null     int64
# ...

# %%
data["Target"].value_counts()
# Out:
# Target
# R     30
# NR    23
# Name: count, dtype: int64

# %% [markdown]
# After doing this initial Data exploration, I know that:
#
# 1. The dataset is 53 rows x 23 columns long
#
# 2. The Unnamed column is an index column, it can be eliminated.
#
# 3. Data distribution seems to be normalized, no presence of outliers or scaling issues that need to be adressed.
#
# 4. Target variable should be encoded (Ordinal encoder)

# %% [markdown]
# # Data preprocessing

# %%
data_clean= data.drop(columns=["Unnamed: 0"])

data_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 22 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Target        53 non-null     object
#  1   n_rs3188513   53 non-null     int64
#  2   n_rs9960669   53 non-null     int64
#  3   n_rs2602      53 non-null     int64
#  4   n_rs5445365   53 non-null     int64
#  5   n_rs133061    53 non-null     int64
#  6   n_rs10102851  53 non-null     int64
#  7   n_rs8375668   53 non-null     int64
#  8   n_rs3015353   53 non-null     int64
#  9   n_rs3229523   53 non-null     int64
#  10  n_rs6236416   53 non-null     int64
#  11  n_rs5274755   53 non-null     int64
#  12  n_rs9280789   53 non-null     int64
#  13  n_rs2515462   53 non-null     int64
#  14  n_rs9025039   53 non-null     int64
#  15  n_rs94282819  53 non-null     int64
#  16  n_rs344903    53 non-null     int64
#  17  n_rs0370      53 non-null     int64
# ...

# %% [markdown]
# This imbalance on the Target will likely be a factor to take into account when interpreting the results. The less present value "NR" will be affected by overfitting, and more prone to be incorrectly classificated by the algorithms.

# %% [markdown]
# # Data split

# %% [markdown]
# First, I will split the data in train and test.

# %%
from sklearn.model_selection import train_test_split

#Create the X (features) and Y (target) datasets
X = data_clean.drop(columns=['Target'])
y = data_clean['Target']

#Split into train and test. Why do I use stratify=y? Why test_size=0.3?
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=42,stratify=y)

print("Size of training-evaluation data:", X_train.shape)
print("Size of test data:", X_test.shape)
# Out:
# Size of training-evaluation data: (31, 21)
# Size of test data: (22, 21)

# %% [markdown]
# # Pipeline

# %%
from sklearn.model_selection import GridSearchCV, LeaveOneOut, cross_val_predict
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, accuracy_score

BEST_MODEL = None

#Define the function for the hyperparameter tuning
def hyperparameter_tuning(X_train, y_train, model, param_grid, cv):
    """
    Perform hyperparameter tuning using GridSearchCV with the provided model and parameter grid.

    Parameters:
    - X_train: Training features.
    - y_train: Training labels.
    - model: A machine learning model.
    - param_grid: Parameter grid for tuning.
    - cv: Cross-validation strategy .

    Returns:
    - best_model: The best model after hyperparameter tuning.
    - best_params: Best hyperparameters.
    - best_score: Best score achieved on validation (accuracy).
    """
    #Create the gridsearch
    grid_search = GridSearchCV(
        estimator=model,
        param_grid=param_grid,
        cv=cv,
        scoring='accuracy',
        verbose=1
    )

    grid_search.fit(X_train, y_train)

    print("Best model is:", grid_search.best_estimator_)
    print("Best parameters are:", grid_search.best_params_)
    print("Best accuracy score in model validation:", grid_search.best_score_)

     # Store the best model in the global variable
    global BEST_MODEL
    BEST_MODEL = grid_search.best_estimator_


    return grid_search.best_estimator_, grid_search.best_params_, grid_search.best_score_

#Define the function for the training data performance report
def training_prediction(X_train, y_train, best_model, cv):
    """
        This function creates the accuracy and classification report 
        for the training and prediction of the whole training data

        Parameters:
        - X_train: Training features.
        - y_train: Training labels.
        - best_model: Tuned machine learning model.
        - cv: Cross-validation strategy.

        Returns:
        -train_classification_report: Classification report from the best model with the training data.

    """
    # Predicting on the training data with cross-validation.
    y_train_pred = cross_val_predict(best_model, X_train, y_train, cv=cv)

    # Generate classification report for the training data.
    train_classification_report = classification_report(y_train, y_train_pred, target_names=["NR", "R"])

    # Output results
    print("Classification Report for Training Data with crossvalidation:\n", train_classification_report)

#Define the function for the test data performance report
def test_prediction_and_matrix(X_test, y_test, best_model, cv):
    """
    This function creates the accuracy and classification report 
    for the test data prediction.

    Parameters:
    - X_test: Test features.
    - y_test: Test labels.
    - best_model: Tuned machine learning model.
    - cv: Number of cross-validation folds or strategy.

    Returns:
    -test_classification_report: Classification report from the best model with the test data.
    -test_accuracy: Accuracy from the best model with the test data.

    """
    
    # Predicting on the test data with cross-validation 
    y_test_pred = best_model.predict(X_test)

    # Generate classification report for the test data.
    test_classification_report = classification_report(y_test, y_test_pred, target_names=["NR", "R"])
    test_accuracy= accuracy_score(y_test,y_test_pred)

    # Output results
    print("Best model accuracy (Test):", test_accuracy )
    print(f"Classification Report for Test Data\n", test_classification_report)

    #Plot the confussion matrix
    cm = confusion_matrix(y_test, y_test_pred, labels=["NR", "R"])

    # Plot the confusion matrix
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["NR", "R"])
    disp.plot(cmap='Blues')

#Pipeline that combines the 3 previous functions.
def model_pipeline(X_train, y_train, X_test, y_test, model, param_grid, cv):
    """
    Pipeline to perform hyperparameter tuning, training prediction, and test prediction.

    Parameters:
    - X_train: Training features.
    - y_train: Training labels.
    - X_test: Test features.
    - y_test: Test labels.
    - model: A machine learning model.
    - param_grid: Parameter grid for tuning.
    - cv: Cross-validation strategy.

    Returns:
    - best_model: The best model after hyperparameter tuning.
    - best_params: Best hyperparameters.
    - best_score: Best score achieved on validation (accuracy).
    """
    #  Hyperparameter tuning
    best_model, best_params, best_score = hyperparameter_tuning(X_train, y_train, model, param_grid, cv)
    
    
    # Training prediction and performance report
    training_prediction(X_train, y_train, best_model, cv)
    
    #  Test prediction and performance report
    test_prediction_and_matrix(X_test, y_test, best_model, cv)

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr_model= LogisticRegression(random_state=42)
LOOVC=LeaveOneOut()
lr_paramgrid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'max_iter': [100, 200, 500, 1000],
    'solver': ['liblinear', 'lbfgs']
}

model_pipeline(X_train,y_train,X_test,y_test,lr_model,lr_paramgrid,LOOVC)
# Out:
# Fitting 31 folds for each of 40 candidates, totalling 1240 fits
# Best model is: LogisticRegression(C=1, random_state=42)
# Best parameters are: {'C': 1, 'max_iter': 100, 'solver': 'lbfgs'}
# Best accuracy score in model validation: 0.9354838709677419
# Classification Report for Training Data with crossvalidation:
#                precision    recall  f1-score   support
#
#           NR       0.92      0.92      0.92        13
#            R       0.94      0.94      0.94        18
#
#     accuracy                           0.94        31
#    macro avg       0.93      0.93      0.93        31
# weighted avg       0.94      0.94      0.94        31
#
# Best model accuracy (Test): 0.9545454545454546
# Classification Report for Test Data
#                precision    recall  f1-score   support
#
#           NR       0.91      1.00      0.95        10
#            R       1.00      0.92      0.96        12
#
#     accuracy                           0.95        22
# ...

# %% [markdown]
# Logistic Regression interpretation

# %%
feature_names= data_clean.drop(columns=["Target"]).columns

# Extract coefficients and intercept
coefficients = BEST_MODEL.coef_[0]  # Coefficients for each feature
intercept = BEST_MODEL.intercept_[0]  # Intercept (bias term)

    # Compute odds ratios
odds_ratios = np.exp(coefficients)

    # Create a DataFrame to display feature importance
feature_importance = pd.DataFrame({
        "Feature": feature_names,
        "Coefficient": coefficients,
        "Odds Ratio": odds_ratios
    }).sort_values(by="Coefficient", ascending=False)

    # Print the intercept and feature importance
print("Intercept:", intercept)
print("\nFeature Importance:")
print(feature_importance)

    # Visualize the feature importance using a bar chart
plt.figure(figsize=(8, 6))
plt.barh(feature_importance["Feature"], feature_importance["Coefficient"], color="skyblue")
plt.axvline(0, color="red", linestyle="--", linewidth=1)
plt.xlabel("Coefficient")
plt.title("Feature Importance (Logistic Regression Coefficients)")
plt.tight_layout()
plt.show()
# Out:
# Intercept: 9.90815613084006
#
# Feature Importance:
#          Feature  Coefficient  Odds Ratio
# 1    n_rs9960669     0.172477    1.188245
# 20    n_rs933069     0.147201    1.158587
# 9    n_rs6236416    -0.023308    0.976962
# 7    n_rs3015353    -0.039957    0.960831
# 2       n_rs2602    -0.058898    0.942803
# 19    n_rs833068    -0.116901    0.889673
# 14  n_rs94282819    -0.145838    0.864297
# 6    n_rs8375668    -0.281323    0.754784
# 12   n_rs2515462    -0.365129    0.694107
# 18      n_rs0220    -0.410488    0.663327
# 11   n_rs9280789    -0.414122    0.660920
# 17   n_rs9072249    -0.532540    0.587112
# 5   n_rs10102851    -0.541458    0.581899
# 16      n_rs0370    -0.545248    0.579698
# 13   n_rs9025039    -0.592502    0.552942
# 4     n_rs133061    -0.606813    0.545086
# 8    n_rs3229523    -0.677520    0.507875
# 3    n_rs5445365    -0.752934    0.470983
# 15    n_rs344903    -0.779900    0.458452
# 10   n_rs5274755    -0.800890    0.448929
# ...

# %% [markdown]
# # Decision Trees

# %%
from sklearn.tree import DecisionTreeClassifier

tree_model= DecisionTreeClassifier(random_state=42)
LOOVC=LeaveOneOut()
tree_paramgrid = {
    'criterion': ['gini', 'entropy'],
    'splitter': ['best', 'random'],
    'max_depth': [None, 10, 20, 30, 40, 50],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

model_pipeline(X_train,y_train,X_test,y_test,tree_model,tree_paramgrid,LOOVC)
# Out:
# Fitting 31 folds for each of 216 candidates, totalling 6696 fits
# Best model is: DecisionTreeClassifier(min_samples_leaf=2, random_state=42)
# Best parameters are: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 2, 'min_samples_split': 2, 'splitter': 'best'}
# Best accuracy score in model validation: 0.8387096774193549
# Classification Report for Training Data with crossvalidation:
#                precision    recall  f1-score   support
#
#           NR       0.75      0.92      0.83        13
#            R       0.93      0.78      0.85        18
#
#     accuracy                           0.84        31
#    macro avg       0.84      0.85      0.84        31
# weighted avg       0.86      0.84      0.84        31
#
# Best model accuracy (Test): 0.6363636363636364
# Classification Report for Test Data
#                precision    recall  f1-score   support
#
#           NR       0.67      0.40      0.50        10
# ...

# %% [markdown]
# Plot the feature importance

# %%
feature_importances = pd.DataFrame({
    'Feature': feature_names, 
    'Importance': BEST_MODEL.feature_importances_
}).sort_values(by='Importance', ascending=False)

print(feature_importances)

# Visualize feature importance
plt.figure(figsize=(8, 6))
plt.barh(feature_importances['Feature'], feature_importances['Importance'], color='skyblue')
plt.xlabel('Importance')
plt.title('Feature Importance in Decision Tree')
plt.tight_layout()
plt.show()
# Out:
#          Feature  Importance
# 15    n_rs344903    0.372470
# 17   n_rs9072249    0.283753
# 8    n_rs3229523    0.283753
# 4     n_rs133061    0.060025
# 0    n_rs3188513    0.000000
# 12   n_rs2515462    0.000000
# 19    n_rs833068    0.000000
# 18      n_rs0220    0.000000
# 16      n_rs0370    0.000000
# 14  n_rs94282819    0.000000
# 13   n_rs9025039    0.000000
# 10   n_rs5274755    0.000000
# 11   n_rs9280789    0.000000
# 1    n_rs9960669    0.000000
# 9    n_rs6236416    0.000000
# 7    n_rs3015353    0.000000
# 6    n_rs8375668    0.000000
# 5   n_rs10102851    0.000000
# 3    n_rs5445365    0.000000
# 2       n_rs2602    0.000000
# 20    n_rs933069    0.000000

# %% [markdown]
# Plot the Decision Tree

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
plot_tree(BEST_MODEL, feature_names=feature_names, class_names=['NR', 'R'], filled=True)
plt.title("Decision Tree Visualization")
plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf_model= RandomForestClassifier(random_state=42)
LOOVC=LeaveOneOut()
rf_paramgrid = {
    'n_estimators': [10, 50, 100, 200],
    'max_depth': [10, 20, 30, 40],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
}

model_pipeline(X_train, y_train, X_test, y_test, rf_model, rf_paramgrid, LOOVC)
# Out:
# Fitting 31 folds for each of 144 candidates, totalling 4464 fits
# Best model is: RandomForestClassifier(max_depth=10, random_state=42)
# Best parameters are: {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}
# Best accuracy score in model validation: 0.9354838709677419
# Classification Report for Training Data with crossvalidation:
#                precision    recall  f1-score   support
#
#           NR       1.00      0.85      0.92        13
#            R       0.90      1.00      0.95        18
#
#     accuracy                           0.94        31
#    macro avg       0.95      0.92      0.93        31
# weighted avg       0.94      0.94      0.93        31
#
# Best model accuracy (Test): 0.9090909090909091
# Classification Report for Test Data
#                precision    recall  f1-score   support
#
#           NR       1.00      0.80      0.89        10
#            R       0.86      1.00      0.92        12
#
# ...

# %% [markdown]
# # KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn_model= KNeighborsClassifier()
LOOVC=LeaveOneOut()
knn_paramgrid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan', 'minkowski']
}

model_pipeline(X_train, y_train, X_test, y_test, knn_model, knn_paramgrid, LOOVC)
# Out:
# Fitting 31 folds for each of 30 candidates, totalling 930 fits
# Best model is: KNeighborsClassifier(metric='euclidean', n_neighbors=3)
# Best parameters are: {'metric': 'euclidean', 'n_neighbors': 3, 'weights': 'uniform'}
# Best accuracy score in model validation: 0.9032258064516129
# Classification Report for Training Data with crossvalidation:
#                precision    recall  f1-score   support
#
#           NR       0.92      0.85      0.88        13
#            R       0.89      0.94      0.92        18
#
#     accuracy                           0.90        31
#    macro avg       0.91      0.90      0.90        31
# weighted avg       0.90      0.90      0.90        31
#
# Best model accuracy (Test): 0.8636363636363636
# Classification Report for Test Data
#                precision    recall  f1-score   support
#
#           NR       0.82      0.90      0.86        10
#            R       0.91      0.83      0.87        12
#
# ...

# %% [markdown]
# # MLP

# %%
from sklearn.neural_network import MLPClassifier

mlp_model= MLPClassifier(random_state=42)
LOOVC=LeaveOneOut()
mlp_paramgrid = {
    'hidden_layer_sizes': [(50,), (100,), (50, 50), (100, 50)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant', 'adaptive'],
}

model_pipeline(X_train, y_train, X_test, y_test, mlp_model, mlp_paramgrid, LOOVC)
# Out:
# Fitting 31 folds for each of 64 candidates, totalling 1984 fits
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# ...
